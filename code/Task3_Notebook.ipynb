# %%
from __future__ import division
import numpy as np
from matplotlib import pyplot as plt
# %pylab inline
from os import chdir
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Task 3

# %% [markdown]
# ### 2D projection of the conformations during reconnaissance

# %%
# for S1

chdir ("/Users/paulvercoustre/Documents/Education/Centrale_ESSEC/Geometric_Methods_in_Data_Analysis/Project/Data/S1")
S1_dist = np.loadtxt("S1_dist_matrix.txt",delimiter=" ",usecols=range(1103))

from sklearn import manifold
from sklearn.metrics import euclidean_distances

seed = 1 #generate reproducable results

mds_lrmsd = manifold.MDS(n_components=2, max_iter=3000, eps=1e-9, random_state=seed, 
                         dissimilarity="precomputed", n_jobs = -1, verbose = True)

T_dist_mds = mds_lrmsd.fit_transform(S1_dist)

fig, ax = plt.subplots()
ax.scatter(T_dist_mds[:, 0], T_dist_mds[:, 1])

plt.xticks(np.linspace(-4, 4, num=9))
plt.yticks(np.linspace(-4, 4, num=9))
plt.title("2D MDS on S1")
#plt.show()
plt.savefig('MDS_S1.png')
# Out:
# breaking at iteration 2595 with stress 34065.280903

# %%
chdir ("/Users/paulvercoustre/Documents/Education/Centrale_ESSEC/Geometric_Methods_in_Data_Analysis/Project/Data/S2")
S2_dist = np.loadtxt("S2_dist_matrix.txt",delimiter=" ",usecols=range(1103))

from sklearn import manifold
from sklearn.metrics import euclidean_distances

seed = 1 #generate reproducable results

mds_lrmsd = manifold.MDS(n_components=2, max_iter=3000, eps=1e-9, random_state=seed, 
                         dissimilarity="precomputed", n_jobs = -1, verbose = True)

T_dist_mds = mds_lrmsd.fit_transform(S2_dist)

fig, ax = plt.subplots()
ax.scatter(T_dist_mds[:, 0], T_dist_mds[:, 1])

plt.xticks(np.linspace(-4, 4, num=9))
plt.yticks(np.linspace(-4, 4, num=9))
plt.title("2D MDS on S2")
#plt.show()
plt.savefig('MDS_S2.png')
# Out:
# breaking at iteration 2127 with stress 75491.7797894
# breaking at iteration 2142 with stress 78994.3344135
# breaking at iteration 2207 with stress 75863.3601564

# %% [markdown]
# ### Histogram for the distribution of distances between pairs of frames

# %% [markdown]
# ##### S1

# %%
chdir ('/Users/paulvercoustre/Documents/Education/Centrale_ESSEC/Geometric_Methods_in_Data_Analysis/Project/Data/S1')
S1_dist = np.loadtxt('S1_dist_pairwise.txt',delimiter=" ")

# %%
# histogram
pylab.xlim([0,3.5])
h = plt.hist(S1_dist[:,2], bins=200, color='blue', histtype='stepfilled')
plt.title("Distribution of distances between pairs of frames - S1")
plt.xlabel('Distances')
plt.ylabel('Frequences of distances')
#plt.show()
plt.savefig('S1_all_dist.png')

# log histogram
pylab.xlim([0,3.5])
h_log = plt.hist(S1_dist[:,2], bins=200, color='blue', histtype='stepfilled', log='False')
plt.yscale('log')
plt.title("Log-distribution of distances between pairs of frames - S1")
plt.xlabel('Distances')
plt.ylabel('Frequences of distances')
#plt.show()
plt.savefig('S1_all_logdist.png')

# %%
import seaborn as sns

# histogram curve
pylab.xlim([0,3.5])
sns.distplot(S1_dist[:,2], hist=False)
plt.title("Histogram curve for the distribution of distances between pairs of frames - S1")
plt.xlabel('Distances')
plt.ylabel('Frequences of distances')
#plt.show()
plt.savefig('S1_all_dist_curve.png')

# log-histogram curve
pylab.xlim([0,3.5])
sns.distplot(S1_dist[:,2], hist=False)
plt.yscale('log')
plt.title("Histogram curve for the log-distribution of distances between pairs of frames - S1")
plt.xlabel('Distances')
plt.ylabel('Frequences of distances')
#plt.show()
plt.savefig('S1_all_logdist_curve.png')

# %% [markdown]
# ### S2

# %%
chdir ('/Users/paulvercoustre/Documents/Education/Centrale_ESSEC/Geometric_Methods_in_Data_Analysis/Project/Data/S2')
S2_dist = np.loadtxt('S2_dist_pairwise.txt',delimiter=" ")

# %%
# histogram
pylab.xlim([0,3.5])
h = plt.hist(S2_dist[:,2], bins=200, color='blue', histtype='stepfilled')
plt.title("Distribution of distances between pairs of frames - S2")
plt.xlabel('Distances')
plt.ylabel('Frequences of distances')
#plt.show()
plt.savefig('S2_all_dist.png')

# log histogram
pylab.xlim([0,3.5])
h_log = plt.hist(S2_dist[:,2], bins=200, color='blue', histtype='stepfilled', log='False')
plt.yscale('log')
plt.title("Log-distribution of distances between pairs of frames - S2")
plt.xlabel('Distances')
plt.ylabel('Frequences of distances')
#plt.show()
plt.savefig('S2_all_logdist.png')

# %%
# histogram curve
pylab.xlim([0,3.5])
sns.distplot(S2_dist[:,2], hist=False)
plt.title("Histogram curve for the distribution of distances between pairs of frames - S2")
plt.xlabel('Distances')
plt.ylabel('Frequences of distances')
#plt.show()
plt.savefig('S2_all_dist_curve.png')

# log-histogram curve
pylab.xlim([0,3.5])
sns.distplot(S2_dist[:,2], hist=False)
plt.yscale('log')
plt.title("Histogram curve for the log-distribution of distances between pairs of frames - S2")
plt.xlabel('Distances')
plt.ylabel('Frequences of distances')
#plt.show()
plt.savefig('S2_all_logdist_curve.png')
